# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# !pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3MB 4.5MB/s
# ...

# %%
import tensorflow as tf
import dlib
import cv2
import os
import re
import json
from pylab import *
from PIL import Image, ImageChops, ImageEnhance
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
train_folder = 'train_sample_videos'
with open(os.path.join(train_frame_folder, 'metadata.json'), 'r') as file:
    data = json.load(file)
train_data = [f for f in os.listdir(train_frame_folder) if f.endswith('.mp4')]
detector = dlib.get_frontal_face_detector()
for video in list_of_train_data:
    count = 0
    capture = cv2.VideoCapture(os.path.join(train_frame_folder, vid))
    frameRate = cap.get(5)
    while capture.isOpened():
            frameid = capture.get(1)
            ret, frame = capture.read()
            if ret != True:
                break
            if frameid % ((int(frameRate)+1)*1) == 0:
                # create the detector, using default weights
                  detector = MTCNN()
                # detect faces in the image
                  faces = detector.detect_faces(frame)
                  for i, d in enumerate(faces):
                        x1 = d['box'][0]
                        y1 = d['box'][1]
                        x2 = d['box'][2]
                        y2 = d['box'][3]
                        crop_image = frame[y1:y1+y2, x1:x1+x2, :]

                        if data[video]['label'] == 'REAL':
                          cv2.imwrite('dataset1/real/'+vid.split('.')[0]+'_'+str(count)+'.png', cv2.resize(crop_img, (128,128)))
                        elif data[video]['label'] == 'FAKE':
                          cv2.imwrite('dataset1/fake/'+vid.split('.')[0]+'_'+str(count)+'.png', cv2.resize(crop_img, (128,128)))
                        count+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-8a2c34e67ce3> in <module>()
#       1 train_frame_folder = 'train_sample_videos'
# ----> 2 with open(os.path.join(train_frame_folder, 'metadata.json'), 'r') as file:
#       3     data = json.load(file)
#       4 list_of_train_data = [f for f in os.listdir(train_frame_folder) if f.endswith('.mp4')]
#       5 detector = dlib.get_frontal_face_detector()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_sample_videos/metadata.json'
